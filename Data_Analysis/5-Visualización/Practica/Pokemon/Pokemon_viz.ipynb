# %% [markdown]
# # Pokemon **

# %% [markdown]
# ### Step 1. Importa las librerías necesarias

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# ### Step 2. Activa matplotlib de forma estática

# %% [markdown]
# ### Step 3. Lee 'Pokemon.csv', lee la primera columna del csv como índice del DataFrame

# %%
pokemon  = pd.read_csv(r'C:/Users/laura/Desktop/DS_PT_09_2023/Data_Analysis/5-Visualización/Practica/Pokemon/Pokemon.csv')

# %% [markdown]
# ### Step 4. Mira las primeras filas del dataset para hacerte una idea de los datos cargados

# %%
pokemon.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# 0     45      1      False
# 1     60      2      False
# 2     80      3      False
# 3     65      1      False
# 4     80      2      False

# %% [markdown]
# ### Step 5. Haz un scatter plot con `lmplot()`, que es el método que pinta una regresión lineal
# Pasa el DataFrame como argumento del método en el parámetro llamado `data`

# %%
plt.figure(figsize=(12,5))
sns.lmplot(data=pokemon, x =  'Attack', y = 'Defense')
plt.xlim(0,140)
plt.xlim(0,175);
# por qué no funciona?

# %% [markdown]
# ### Step 6. No queremos ver la línea recta de la regresión lineal.
# Prueba a añadir fit_reg a falso

# %%
plt.figure(figsize=(12,5))
sns.lmplot(data=pokemon, x =  'Attack', y = 'Defense', fit_reg=False)

# %% [markdown]
# ### Step 7. Vamos a decir qué variable (columna del DataFrame) codifica los colores (hue)
# Que el `hue` sea el Stage

# %%
plt.figure(figsize=(12,5))
sns.lmplot(data=pokemon, x =  'Attack', y = 'Defense',hue='Stage' ,fit_reg=False);

# %% [markdown]
# ### Step 8. Limita el eje x entre 20 y 100

# %%
plt.figure(figsize=(12,5))
sns.lmplot(data=pokemon, x =  'Attack', y = 'Defense',hue='Stage' ,fit_reg=False)
plt.xlim(20,100);

# %% [markdown]
# ### Step 9. Dibuja un diagrama de cajas con el dataframe

# %%
sns.catplot( data=pokemon, kind='box', aspect=2);

# %% [markdown]
# ### Step 10. No nos interesan las columnas Total, Stage ni Legendary
# Bórralos del DataFrame y vuelve a dibujar el diagrama de cajas

# %%
pokemon_2 = pokemon.drop(['Total', 'Stage', 'Legendary'], axis=1)

sns.catplot( data=pokemon_2, kind='box', aspect=2);

# %% [markdown]
# ### Step 11. Mira cuántos 'Type 1' diferentes hay en el DataFrame

# %%
pokemon['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon'], dtype=object)

# %%
pokemon['Type 1'].nunique()
# Out:
# 15

# %% [markdown]
# ### Step 12. Quédate del Dataframe solo con los 'Type 1' iguales a 'Grass', 'Fire' o 'Water'

# %%
selected_types = ['Grass', 'Fire', 'Water']

filtered_pokemon = pokemon[pokemon['Type 1'].isin(selected_types)]
filtered_pokemon
# Out:
#        #        Name Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur  Grass    Poison    318   45      49       49       65
# 1      2     Ivysaur  Grass    Poison    405   60      62       63       80
# 2      3    Venusaur  Grass    Poison    525   80      82       83      100
# 3      4  Charmander   Fire       NaN    309   39      52       43       60
# 4      5  Charmeleon   Fire       NaN    405   58      64       58       80
# 5      6   Charizard   Fire    Flying    534   78      84       78      109
# 6      7    Squirtle  Water       NaN    314   44      48       65       50
# 7      8   Wartortle  Water       NaN    405   59      63       80       65
# 8      9   Blastoise  Water       NaN    530   79      83      100       85
# 36    37      Vulpix   Fire       NaN    299   38      41       40       50
# 37    38   Ninetales   Fire       NaN    505   73      76       75       81
# 42    43      Oddish  Grass    Poison    320   45      50       55       75
# 43    44       Gloom  Grass    Poison    395   60      65       70       85
# 44    45   Vileplume  Grass    Poison    490   75      80       85      110
# 53    54     Psyduck  Water       NaN    320   50      52       48       65
# 54    55     Golduck  Water       NaN    500   80      82       78       95
# 57    58   Growlithe   Fire       NaN    350   55      70       45       70
# 58    59    Arcanine   Fire       NaN    555   90     110       80      100
# 59    60     Poliwag  Water       NaN    300   40      50       40       40
# 60    61   Poliwhirl  Water       NaN    385   65      65       65       50
# 61    62   Poliwrath  Water  Fighting    510   90      95       95       70
# 68    69  Bellsprout  Grass    Poison    300   50      75       35       70
# 69    70  Weepinbell  Grass    Poison    390   65      90       50       85
# 70    71  Victreebel  Grass    Poison    490   80     105       65      100
# 71    72   Tentacool  Water    Poison    335   40      40       35       50
# 72    73  Tentacruel  Water    Poison    515   80      70       65       80
# 76    77      Ponyta   Fire       NaN    410   50      85       55       65
# 77    78    Rapidash   Fire       NaN    500   65     100       70       80
# 78    79    Slowpoke  Water   Psychic    315   90      65       65       40
# 79    80     Slowbro  Water   Psychic    490   95      75      110      100
# 85    86        Seel  Water       NaN    325   65      45       55       45
# 86    87     Dewgong  Water       Ice    475   90      70       80       70
# 89    90    Shellder  Water       NaN    305   30      65      100       45
# 90    91    Cloyster  Water       Ice    525   50      95      180       85
# 97    98      Krabby  Water       NaN    325   30     105       90       25
# 98    99     Kingler  Water       NaN    475   55     130      115       50
# 101  102   Exeggcute  Grass   Psychic    325   60      40       80       60
# 102  103   Exeggutor  Grass   Psychic    520   95      95       85      125
# 113  114     Tangela  Grass       NaN    435   65      55      115      100
# 115  116      Horsea  Water       NaN    295   30      40       70       70
# 116  117      Seadra  Water       NaN    440   55      65       95       95
# 117  118     Goldeen  Water       NaN    320   45      67       60       35
# 118  119     Seaking  Water       NaN    450   80      92       65       65
# 119  120      Staryu  Water       NaN    340   30      45       55       70
# 120  121     Starmie  Water   Psychic    520   60      75       85      100
# 125  126      Magmar   Fire       NaN    495   65      95       57      100
# 128  129    Magikarp  Water       NaN    200   20      10       55       15
# 129  130    Gyarados  Water    Flying    540   95     125       79       60
# 130  131      Lapras  Water       Ice    535  130      85       80       85
# 133  134    Vaporeon  Water       NaN    525  130      65       60      110
# 135  136     Flareon   Fire       NaN    525   65     130       60       95
# 145  146     Moltres   Fire    Flying    580   90     100       90      125
#
#      Sp. Def  Speed  Stage  Legendary
# 0         65     45      1      False
# 1         80     60      2      False
# 2        100     80      3      False
# 3         50     65      1      False
# 4         65     80      2      False
# 5         85    100      3      False
# 6         64     43      1      False
# 7         80     58      2      False
# 8        105     78      3      False
# 36        65     65      1      False
# 37       100    100      2      False
# 42        65     30      1      False
# 43        75     40      2      False
# 44        90     50      3      False
# 53        50     55      1      False
# 54        80     85      2      False
# 57        50     60      1      False
# 58        80     95      2      False
# 59        40     90      1      False
# 60        50     90      2      False
# 61        90     70      3      False
# 68        30     40      1      False
# 69        45     55      2      False
# 70        70     70      3      False
# 71       100     70      1      False
# 72       120    100      2      False
# 76        65     90      1      False
# 77        80    105      2      False
# 78        40     15      1      False
# 79        80     30      2      False
# 85        70     45      1      False
# 86        95     70      2      False
# 89        25     40      1      False
# 90        45     70      2      False
# 97        25     50      1      False
# 98        50     75      2      False
# 101       45     40      1      False
# 102       65     55      2      False
# 113       40     60      1      False
# 115       25     60      1      False
# 116       45     85      2      False
# 117       50     63      1      False
# 118       80     68      2      False
# 119       55     85      1      False
# 120       85    115      2      False
# 125       85     93      1      False
# 128       20     80      1      False
# 129      100     81      2      False
# 130       95     60      1      False
# 133       95     65      2      False
# 135      110     65      2      False
# 145       85     90      1       True

# %% [markdown]
# ### Step 13. Usa un estilo 'whitegrid'

# %% [markdown]
# ### Step 14. Pinta diagramas de violín con el DataFrame

# %%
sns.catplot( x='Type 1' , y= 'Attack' , data=filtered_pokemon, kind='violin', aspect=2);

# %% [markdown]
# ### Step 15. Escribe una lista de colores con valores '#78C850', '#F08030',  '#6890F0'

# %%
colors = [ '#78C850', '#F08030',  '#6890F0']

# %% [markdown]
# ### Step 16. Pinta de nuevo los diagramas de violín añadiendo esos colores en la paleta (palette)

# %%
sns.catplot( x='Type 1' , y= 'Attack' , data=filtered_pokemon, kind='violin',palette=colors, aspect=2);
# Out:
# C:\Users\laura\AppData\Local\Temp\ipykernel_19268\4202643294.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot( x='Type 1' , y= 'Attack' , data=filtered_pokemon, kind='violin',palette=colors, aspect=2);

# %% [markdown]
# ### Step 17. Con el diagrama de violín vemos la forma de la distribución, pero no sabemos si Grass tiene muchos puntos y Fire tiene muy pocos.
# - Para ver esto, usamos el swarmplot.
# - Pinta el último diagrama de violines pero con un swarmplot en lugar de un violin

# %%
sns.catplot( x='Type 1' , y= 'Attack' , data=filtered_pokemon, kind='swarm',palette=colors, aspect=1, legend=False);
# Out:
# C:\Users\laura\AppData\Local\Temp\ipykernel_19268\2994992995.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot( x='Type 1' , y= 'Attack' , data=filtered_pokemon, kind='swarm',palette=colors, aspect=1, legend=False);

# %% [markdown]
# ### Step 18. Queremos ver los violines a la vez que los swarm, los podemos pintar juntos.
# Elimina los diagramas de caja dentro de los violines con el parámetro inner = None y pon una transparencia de 0.9

# %%
sns.catplot( x='Type 1' , y= 'Attack' , data=filtered_pokemon, kind='swarm',palette=colors, aspect=1, legend=False, alpha=0.7)

sns.catplot( x='Type 1' , y= 'Attack' , data=filtered_pokemon, kind='violin',palette=colors, aspect=2, inner = None, );
# Out:
# C:\Users\laura\AppData\Local\Temp\ipykernel_19268\948073222.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot( x='Type 1' , y= 'Attack' , data=filtered_pokemon, kind='swarm',palette=colors, aspect=1, legend=False, alpha=0.7)
# C:\Users\laura\AppData\Local\Temp\ipykernel_19268\948073222.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot( x='Type 1' , y= 'Attack' , data=filtered_pokemon, kind='violin',palette=colors, aspect=2, inner = None, );

# %% [markdown]
# ### Step 19. Veamos la función melt() de pandas. Melt toma los valores de varias columnas y los junta todos en una misma columna nueva.
#  Dado un DataFrame, [melt](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.melt.html) recibe varios parámetros:
#  * qué columnas del DataFrame se quedan igual
#  * qué nombres de columnas del dataframe pasan a ser una columna nueva
#  * cómo queremos llamar esas nuevas columnas
#
# Primero recuerda el Dataframe `df_grass_fire_water` con las primeras 5 filas

# %%
filtered_pokemon.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Stage', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ### Step 20. Queremos dejar igual las variables 'Name' y 'Type 1'
# Queremos añadir una columa nueva cuyos valores sean las columnas que queremos apilar y que se llame 'New Column'
#
# Escribimos `df_grass_fire_water.melt(id_vars=['Name', 'Type 1'], value_vars=[...], var_name='New Column')`

# %%
melted = filtered_pokemon.melt(id_vars=['Name', 'Type 1'], var_name='New Column')

# %%
# Out:
#          Name Type 1 Melted value
# 0   Bulbasaur  Grass     HP    45
# 1     Ivysaur  Grass     HP    60
# 2    Venusaur  Grass     HP    80
# 3  Charmander   Fire     HP    39
# 4  Charmeleon   Fire     HP    58

# %% [markdown]
# ### Step 21. Pintamos el swarmplot con el melted y entendemos la información

# %%
sns.catplot(y= 'value' , data=melted, kind='swarm',palette=colors, aspect=1, legend=False, alpha=0.7)
# Out:
# C:\Users\laura\AppData\Local\Temp\ipykernel_19268\1952015645.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(y= 'value' , data=melted, kind='swarm',palette=colors, aspect=1, legend=False, alpha=0.7)
# C:\Users\laura\AppData\Local\Temp\ipykernel_19268\1952015645.py:1: UserWarning: The palette list has more values (3) than needed (1), which may not be intended.
#   sns.catplot(y= 'value' , data=melted, kind='swarm',palette=colors, aspect=1, legend=False, alpha=0.7)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File lib.pyx:2368, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Poison"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# c:\Users\laura\Desktop\DS_PT_09_2023\Data_Analysis\5-Visualización\Practica\Pokemon\Pokemon_viz.ipynb Cell 47 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/laura/Desktop/DS_PT_09_2023/Data_Analysis/5-Visualizaci%C3%B3n/Practica/Pokemon/Pokemon_viz.ipynb#Y122sZmlsZQ%3D%3D?line=0'>1</a> sns.catplot(y= 'value' , data=melted, kind='swarm',palette=colors, aspect=1, legend=False, alpha=0.7)
#
# File c:\Users\laura\Desktop\DS_PT_09_2023\.venv\Lib\site-packages\seaborn\categorical.py:2869, in catplot(data, x, y, hue, row, col, kind, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, col_wrap, height, aspect, log_scale, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    2866     if plot_kws.setdefault("linewidth", 0) is None:
#    2867         plot_kws["linewidth"] = np.sqrt(plot_kws["s"]) / 10
# -> 2869     p.plot_swarms(
#    2870         dodge=dodge,
#    2871         color=color,
#    2872         warn_thresh=warn_thresh,
#    2873         plot_kws=plot_kws,
#    2874     )
#    2876 elif kind == "box":
#    2878     plot_kws = kwargs.copy()
#
# File c:\Users\laura\Desktop\DS_PT_09_2023\.venv\Lib\site-packages\seaborn\categorical.py:531, in _CategoricalPlotter.plot_swarms(self, dodge, color, warn_thresh, plot_kws)
#     528 if "marker" in plot_kws and not MarkerStyle(plot_kws["marker"]).is_filled():
#     529     plot_kws.pop("edgecolor", None)
# --> 531 for sub_vars, sub_data in self.iter_data(iter_vars,
#     532                                          from_comp_data=True,
#     533                                          allow_empty=True):
#     535     ax = self._get_axes(sub_vars)
#     537     if offsets is not None:
#
# File c:\Users\laura\Desktop\DS_PT_09_2023\.venv\Lib\site-packages\seaborn\_base.py:902, in VectorPlotter.iter_data(self, grouping_vars, reverse, from_comp_data, by_facet, allow_empty, dropna)
#     899 grouping_vars = [var for var in grouping_vars if var in self.variables]
#     901 if from_comp_data:
# --> 902     data = self.comp_data
#     903 else:
#     904     data = self.plot_data
#
# File c:\Users\laura\Desktop\DS_PT_09_2023\.venv\Lib\site-packages\seaborn\_base.py:999, in VectorPlotter.comp_data(self)
#     994 if var in self.var_levels:
#     995     # TODO this should happen in some centralized location
#     996     # it is similar to GH2419, but more complicated because
#     997     # supporting `order` in categorical plots is tricky
#     998     orig = orig[orig.isin(self.var_levels[var])]
# --> 999 comp = pd.to_numeric(converter.convert_units(orig)).astype(float)
#    1000 transform = converter.get_transform().transform
#    1001 parts.append(pd.Series(transform(comp), orig.index, name=orig.name))
#
# File c:\Users\laura\Desktop\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\tools\numeric.py:222, in to_numeric(arg, errors, downcast, dtype_backend)
#     220 coerce_numeric = errors not in ("ignore", "raise")
#     221 try:
# --> 222     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]  # noqa: E501
#     223         values,
#     224         set(),
#     225         coerce_numeric=coerce_numeric,
#     226         convert_to_masked_nullable=dtype_backend is not lib.no_default
#     227         or isinstance(values_dtype, StringDtype),
#     228     )
#     229 except (ValueError, TypeError):
#     230     if errors == "raise":
#
# File lib.pyx:2410, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Poison" at position 52

# %% [markdown]
# ### Step 22. Basándote en el gráfico anterior, define el tamaño de la figura en (10,6) (usa plt)
# En el swarmplot añade el argumento dodge a True y usa la anterior paleta de colores Pokemon
#
# Dodge en inglés es "esquivar", ¿qué diferencia ves?
#
# Usando plt:
#   - fija el límite del eje Y entre 0 y 200
#   - fija la leyenda con bbox_to_anchor en upper left. Pista: upper left es el código 2 y se usa el parámetro loc.

# %% [markdown]
# ### Step 23. Mapas de calor
# Calcula las correlaciones del primer DataFrame original df
#
# Las correlaciones miden entre dos variables, si varío una, cuánto me varía la otra (cómo están de relacionadas)

# %%
plt.figure(figsize=(12,9))
sns.heatmap(pokemon.corr(),
           vmin=-1,vmax=1,annot=True,linewidths=0.5);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\laura\Desktop\DS_PT_09_2023\Data_Analysis\5-Visualización\Practica\Pokemon\Pokemon_viz.ipynb Cell 52 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/laura/Desktop/DS_PT_09_2023/Data_Analysis/5-Visualizaci%C3%B3n/Practica/Pokemon/Pokemon_viz.ipynb#Y123sZmlsZQ%3D%3D?line=0'>1</a> plt.figure(figsize=(12,9))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/laura/Desktop/DS_PT_09_2023/Data_Analysis/5-Visualizaci%C3%B3n/Practica/Pokemon/Pokemon_viz.ipynb#Y123sZmlsZQ%3D%3D?line=1'>2</a> sns.heatmap(pokemon.corr(),
#       <a href='vscode-notebook-cell:/c%3A/Users/laura/Desktop/DS_PT_09_2023/Data_Analysis/5-Visualizaci%C3%B3n/Practica/Pokemon/Pokemon_viz.ipynb#Y123sZmlsZQ%3D%3D?line=2'>3</a>            vmin=-1,vmax=1,annot=True,linewidths=0.5);
#
# File c:\Users\laura\Desktop\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\frame.py:10707, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10705 cols = data.columns
#   10706 idx = cols.copy()
# > 10707 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10709 if method == "pearson":
#   10710     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\laura\Desktop\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\frame.py:1892, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1890 if dtype is not None:
#    1891     dtype = np.dtype(dtype)
# -> 1892 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1893 if result.dtype is not dtype:
#    1894     result = np.array(result, dtype=dtype, copy=False)
#
# File c:\Users\laura\Desktop\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\internals\managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File c:\Users\laura\Desktop\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\internals\managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Bulbasaur'

# %% [markdown]
# ### Step 24. Pinta el histograma y la densidad de probabilidad del nivel de defensa usando el DataFrame original

# %% [markdown]
# ### Step 25. Pinta un diagrama de barras de la columna 'Type 1' usando el DataFrame original
# Usa un sns.countplot y plt.xticks para girar las etiquetas

# %% [markdown]
# ### Step 26. Usa catplot con el DataFrame original.
# Muestra el valor de Defense según el 'Type 1', muestra un subplot para legendarios y otro para no legendariosy divide los colores según el Type 2

# %% [markdown]
# ### Step 27. Muestra una función distribución de probabilidad con kdeplot (curvas de nivel) de la defensa respecto al ataque.

# %% [markdown]
# ### Step 29. Pinta una distribución de probabilidad conjunta, pintando la defensa respecto al ataque del DataFrame original
