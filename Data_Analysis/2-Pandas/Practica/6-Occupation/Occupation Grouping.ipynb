# %% [markdown]
# # Occupation

# %% [markdown]
# ### Paso 1. Importar librerias

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Paso 2. Importar el conjunto de datos de esta [dirección](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'
users = pd.read_csv(url, sep= '|' )

# %% [markdown]
# ### Paso 3. Asígnalo a una variable llamada usuarios.

# %%
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# ### Paso 4. Descubre cuál es la edad media por ocupación

# %%
users.groupby('occupation')[['age']].mean()
# Out:
#                      age
# occupation
# administrator  38.746835
# artist         31.392857
# doctor         43.571429
# educator       42.010526
# engineer       36.388060
# entertainment  29.222222
# executive      38.718750
# healthcare     41.562500
# homemaker      32.571429
# lawyer         36.750000
# librarian      40.000000
# marketing      37.615385
# none           26.555556
# other          34.523810
# programmer     33.121212
# retired        63.071429
# salesman       35.666667
# scientist      35.548387
# student        22.081633
# technician     33.148148
# writer         36.311111

# %% [markdown]
# ### Paso 5. Descubra la proporción de Hombres por ocupación y ordénela de mayor a menor

# %% [markdown]
# #### Forma 1

# %%
users.groupby('occupation').describe('gender')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\laura\Desktop\DS_PT_09_2023\Data_Analysis\2-Pandas\Practica\6-Occupation\Occupation Grouping.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/laura/Desktop/DS_PT_09_2023/Data_Analysis/2-Pandas/Practica/6-Occupation/Occupation%20Grouping.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> users.groupby('occupation').describe('gender')
#
# File c:\Users\laura\Desktop\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:3483, in GroupBy.describe(self, percentiles, include, exclude)
#    3480     return result.to_frame().T.iloc[:0]
#    3482 with com.temp_setattr(self, "as_index", True):
# -> 3483     result = self._python_apply_general(
#    3484         lambda x: x.describe(
#    3485             percentiles=percentiles, include=include, exclude=exclude
#    3486         ),
#    3487         obj,
#    3488         not_indexed_same=True,
#    3489     )
#    3490 if self.axis == 1:
#    3491     return result.T
#
# File c:\Users\laura\Desktop\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:1815, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1780 @final
#    1781 def _python_apply_general(
#    1782     self,
#    (...)
#    1787     is_agg: bool = False,
#    1788 ) -> NDFrameT:
#    1789     """
#    1790     Apply function f in python space
#    1791
#    (...)
#    1813         data after applying f
#    1814     """
# -> 1815     values, mutated = self.grouper.apply_groupwise(f, data, self.axis)
#    1816     if not_indexed_same is None:
#    1817         not_indexed_same = mutated
#
# File c:\Users\laura\Desktop\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\groupby\ops.py:905, in BaseGrouper.apply_groupwise(self, f, data, axis)
#     903 # group might be modified
#     904 group_axes = group.axes
# --> 905 res = f(group)
#     906 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     907     mutated = True
#
# File c:\Users\laura\Desktop\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:3484, in GroupBy.describe.<locals>.<lambda>(x)
#    3480     return result.to_frame().T.iloc[:0]
#    3482 with com.temp_setattr(self, "as_index", True):
#    3483     result = self._python_apply_general(
# -> 3484         lambda x: x.describe(
#    3485             percentiles=percentiles, include=include, exclude=exclude
#    3486         ),
#    3487         obj,
#    3488         not_indexed_same=True,
#    3489     )
#    3490 if self.axis == 1:
#    3491     return result.T
#
# File c:\Users\laura\Desktop\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\generic.py:11540, in NDFrame.describe(self, percentiles, include, exclude)
#   11298 @final
#   11299 def describe(
#   11300     self,
#    (...)
#   11303     exclude=None,
#   11304 ) -> Self:
#   11305     """
#   11306     Generate descriptive statistics.
#   11307
#    (...)
#   11538     max            NaN      3.0
#   11539     """
# > 11540     return describe_ndframe(
#   11541         obj=self,
#   11542         include=include,
#   11543         exclude=exclude,
#   11544         percentiles=percentiles,
#   11545     ).__finalize__(self, method="describe")
#
# File c:\Users\laura\Desktop\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\methods\describe.py:83, in describe_ndframe(obj, include, exclude, percentiles)
#      55 def describe_ndframe(
#      56     *,
#      57     obj: NDFrameT,
#    (...)
#      60     percentiles: Sequence[float] | np.ndarray | None,
#      61 ) -> NDFrameT:
#      62     """Describe series or dataframe.
#      63
#      64     Called from pandas.core.generic.NDFrame.describe()
#    (...)
#      81     Dataframe or series description.
#      82     """
# ---> 83     percentiles = _refine_percentiles(percentiles)
#      85     describer: NDFrameDescriberAbstract
#      86     if obj.ndim == 1:
#
# File c:\Users\laura\Desktop\DS_PT_09_2023\.venv\Lib\site-packages\pandas\core\methods\describe.py:400, in _refine_percentiles(percentiles)
#     397 percentiles = list(percentiles)
#     399 # get them all to be in [0, 1]
# --> 400 validate_percentile(percentiles)
#     402 # median should always be included
#     403 if 0.5 not in percentiles:
#
# File c:\Users\laura\Desktop\DS_PT_09_2023\.venv\Lib\site-packages\pandas\util\_validators.py:339, in validate_percentile(q)
#     337         raise ValueError(msg)
#     338 else:
# --> 339     if not all(0 <= qs <= 1 for qs in q_arr):
#     340         raise ValueError(msg)
#     341 return q_arr
#
# File c:\Users\laura\Desktop\DS_PT_09_2023\.venv\Lib\site-packages\pandas\util\_validators.py:339, in <genexpr>(.0)
#     337         raise ValueError(msg)
#     338 else:
# --> 339     if not all(0 <= qs <= 1 for qs in q_arr):
#     340         raise ValueError(msg)
#     341 return q_arr
#
# TypeError: '<=' not supported between instances of 'int' and 'numpy.str_'

# %%
# Out:
#         occupation
# gender
# F              273
# M              670

# %% [markdown]
# #### Forma 2

# %% [markdown]
# #### Forma 3

# %% [markdown]
# ### Paso 6. Para cada ocupación, calcule las edades mínima y máxima

# %%
users.groupby('occupation')[['age']].min()
# Out:
#                age
# occupation
# administrator   21
# artist          19
# doctor          28
# educator        23
# engineer        22
# entertainment   15
# executive       22
# healthcare      22
# homemaker       20
# lawyer          21
# librarian       23
# marketing       24
# none            11
# other           13
# programmer      20
# retired         51
# salesman        18
# scientist       23
# student          7
# technician      21
# writer          18

# %%
users.groupby('occupation')[['age']].max()
# Out:
#                age
# occupation
# administrator   70
# artist          48
# doctor          64
# educator        63
# engineer        70
# entertainment   50
# executive       69
# healthcare      62
# homemaker       50
# lawyer          53
# librarian       69
# marketing       55
# none            55
# other           64
# programmer      63
# retired         73
# salesman        66
# scientist       55
# student         42
# technician      55
# writer          60

# %% [markdown]
# ### Paso 7. Para cada combinación de ocupación y sexo, calcule la edad media

# %% [markdown]
# ### Paso 8.  Para cada ocupación, presente el porcentaje de mujeres y hombres

# %%
users.groupby('occupation')[['gender']].describe()
# Out:
#               gender
#                count unique top freq
# occupation
# administrator     79      2   M   43
# artist            28      2   M   15
# doctor             7      1   M    7
# educator          95      2   M   69
# engineer          67      2   M   65
# entertainment     18      2   M   16
# executive         32      2   M   29
# healthcare        16      2   F   11
# homemaker          7      2   F    6
# lawyer            12      2   M   10
# librarian         51      2   F   29
# marketing         26      2   M   16
# none               9      2   M    5
# other            105      2   M   69
# programmer        66      2   M   60
# retired           14      2   M   13
# salesman          12      2   M    9
# scientist         31      2   M   28
# student          196      2   M  136
# technician        27      2   M   26
# writer            45      2   M   26
